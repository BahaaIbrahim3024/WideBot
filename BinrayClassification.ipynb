# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
trainingData=pd.read_csv('training.csv')
trainingData.head()
# Out:
#   variable1  variable2  variable3 variable4 variable5 variable6 variable7  \
# 0         a      17.92   0.000054         u         g         c         v
# 1         b      16.92   0.000034         y         p         k         v
# 2         b      31.25   0.000112         u         g        ff        ff
# 3         a      48.17   0.000133         u         g         i         o
# 4         b      32.33   0.000350         u         g         k         v
#
#    variable8 variable9 variable10  variable11 variable12 variable13  \
# 0      1.750         f          t           1          t          g
# 1      0.290         f          f           0          f          s
# 2      0.000         f          t           1          f          g
# 3      0.335         f          f           0          f          g
# 4      0.500         f          f           0          t          g
#
#    variable14  variable15  variable17 variable18  variable19 classLabel
# ...

# %% [markdown]
# I can't understand this dataset also what are features here and i can't find a relation between them and the class label, also this data was unorganized i organized it to what you are see now ! But i can't find any thing useful in it.
